# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 2050'

# %%
from ultralytics import YOLO

# Load the model
model = YOLO("yolo11s.pt") #take large model for better trainning 

# Train the model
results = model.train(
    data="D:/bone/data.yaml",  
    epochs=150,
    imgsz=640,
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.217 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.202  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("D:/bone/runs/detect/train/weights/best.pt")
result = model("",save= True)
result[0].show()
# Out:
# image 1/5 D:\bone\imgtest\ap and lateral radiographs of the forearm.jpg: 640x544 1 ulna fracture, 153.7ms
# image 2/5 D:\bone\imgtest\how-to-know-if-your-bone-is-broken-img.webp: 448x640 (no detections), 157.9ms
# image 3/5 D:\bone\imgtest\images (1).jpg: 576x640 (no detections), 143.4ms
# image 4/5 D:\bone\imgtest\images.jpg: 640x480 1 ulna fracture, 143.2ms
# image 5/5 D:\bone\imgtest\xray-film-broken-finger-shattered-600nw-377744002.webp: 640x480 (no detections), 42.7ms
# Speed: 7.8ms preprocess, 128.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to D:\bone\runs\detect\predict3
